# %%
import polars as pl

# %%
cs = pl.read_csv("datasets/2024_constituencies.csv")

# %%
cs.head(5)
# Out:
# shape: (5, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 0         ┆ 801       ┆ 0        │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
mps = cs.select("constituency_name", "mp_firstname", "mp_surname")

# %%
mps
# Out:
# shape: (650, 3)
# ┌─────────────────────────────────┬──────────────┬────────────┐
# │ constituency_name               ┆ mp_firstname ┆ mp_surname │
# │ ---                             ┆ ---          ┆ ---        │
# │ str                             ┆ str          ┆ str        │
# ╞═════════════════════════════════╪══════════════╪════════════╡
# │ Aberafan Maesteg                ┆ Stephen      ┆ Kinnock    │
# │ Aberdeen North                  ┆ Kirsty       ┆ Blackman   │
# │ Aberdeen South                  ┆ Stephen      ┆ Flynn      │
# │ Aberdeenshire North and Moray … ┆ Seamus       ┆ Logan      │
# │ Airdrie and Shotts              ┆ Kenneth      ┆ Stevenson  │
# │ …                               ┆ …            ┆ …          │
# │ Wythenshawe and Sale East       ┆ Mike         ┆ Kane       │
# │ Yeovil                          ┆ Adam         ┆ Dance      │
# │ Ynys Môn                        ┆ Llinos       ┆ Medi       │
# ...

# %%
wales = cs.filter(pl.col("region_name") == "Wales")

# %%
northern_regions = ["North East", "North West"]

# %%
cs.filter(pl.col("region_name").is_in(northern_regions))
# Out:
# shape: (100, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ E14001065 ┆ E12000002 ┆ Altrincha ┆ North     ┆ … ┆ 0         ┆ 0         ┆ 643       ┆ 0        │
# │           ┆           ┆ m and     ┆ West      ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
cs.filter(~ pl.col("region_name").is_in(northern_regions))
# Out:
# shape: (550, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 0         ┆ 801       ┆ 0        │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
cs.sort("majority")
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ E14001279 ┆ E12000007 ┆ Hendon    ┆ London    ┆ … ┆ 0         ┆ 0         ┆ 1890      ┆ 0        │
# │ E14001429 ┆ E12000009 ┆ Poole     ┆ South     ┆ … ┆ 0         ┆ 0         ┆ 1023      ┆ 0        │
# ...

# %%
cs.sort("majority", descending=True)
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ E14001113 ┆ E12000002 ┆ Bootle    ┆ North     ┆ … ┆ 0         ┆ 0         ┆ 526       ┆ 0        │
# │           ┆           ┆           ┆ West      ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
cs.sort(["region_name", "constituency_name"], descending=[False, True])
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ E14001571 ┆ E12000004 ┆ Wellingbo ┆ East      ┆ … ┆ 0         ┆ 0         ┆ 273       ┆ 0        │
# │           ┆           ┆ rough and ┆ Midlands  ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
cs.with_columns( (pl.col("majority") > 10000).alias("safe_seat") )
# Out:
# shape: (650, 31)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_apn ┆ votes_all ┆ votes_oth ┆ safe_sea │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ i         ┆ _other    ┆ er_winner ┆ t        │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆ i64       ┆ i64       ┆ i64       ┆ bool     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 801       ┆ 0         ┆ true     │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# │ S14000060 ┆ S92000003 ┆ Aberdeen  ┆ Scotland  ┆ … ┆ 0         ┆ 1269      ┆ 0         ┆ false    │
# ...

# %%
cs.with_columns(pl.col("declaration_time").str.to_datetime(time_zone="Europe/London"))
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 0         ┆ 801       ┆ 0        │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
