# %%
import polars as pl

# %%
constituencies = pl.read_csv("datasets/2024_constituencies.csv")

# %%
constituencies
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 0         ┆ 801       ┆ 0        │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
pl.Config.set_tbl_rows(4)
# Out:
# polars.config.Config

# %%
constituencies
# Out:
# shape: (650, 30)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ constitue ┆ region_id ┆ constitue ┆ region_na ┆ … ┆ votes_uup ┆ votes_apn ┆ votes_all ┆ votes_ot │
# │ ncy_id    ┆ ---       ┆ ncy_name  ┆ me        ┆   ┆ ---       ┆ i         ┆ _other    ┆ her_winn │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64       ┆ ---       ┆ ---       ┆ er       │
# │ str       ┆           ┆ str       ┆ str       ┆   ┆           ┆ i64       ┆ i64       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ W07000081 ┆ W92000004 ┆ Aberafan  ┆ Wales     ┆ … ┆ 0         ┆ 0         ┆ 801       ┆ 0        │
# │           ┆           ┆ Maesteg   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
pl.Config.set_tbl_cols(-1)
# Out:
# polars.config.Config

# %%
constituencies.head(10)
# Out:
# shape: (10, 30)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ con ┆ reg ┆ con ┆ reg ┆ cou ┆ con ┆ dec ┆ mp_ ┆ mp_ ┆ mp_ ┆ win ┆ sec ┆ ele ┆ val ┆ inv ┆ maj ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot ┆ vot │
# │ sti ┆ ion ┆ sti ┆ ion ┆ ntr ┆ sti ┆ lar ┆ fir ┆ sur ┆ gen ┆ nin ┆ ond ┆ cto ┆ id_ ┆ ali ┆ ori ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ ┆ es_ │
# │ tue ┆ _id ┆ tue ┆ _na ┆ y_n ┆ tue ┆ ati ┆ stn ┆ nam ┆ der ┆ g_p ┆ _pa ┆ rat ┆ vot ┆ d_v ┆ ty  ┆ con ┆ lab ┆ ld  ┆ ruk ┆ gre ┆ snp ┆ pc  ┆ dup ┆ sf  ┆ sdl ┆ uup ┆ apn ┆ all ┆ oth │
# │ ncy ┆ --- ┆ ncy ┆ me  ┆ ame ┆ ncy ┆ on_ ┆ ame ┆ e   ┆ --- ┆ art ┆ rty ┆ e   ┆ es  ┆ ote ┆ --- ┆ --- ┆ --- ┆ --- ┆ --- ┆ en  ┆ --- ┆ --- ┆ --- ┆ --- ┆ p   ┆ --- ┆ i   ┆ _ot ┆ er_ │
# ...
